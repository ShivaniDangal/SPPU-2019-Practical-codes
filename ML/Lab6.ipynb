# %% [markdown]
# ##### Problem statement:
#
# Implement K-Means clustering/ hierarchical clustering on sales_data_sample.csv dataset.
# Determine the number of clusters using the elbow method.
# Dataset link : https://www.kaggle.com/datasets/kyanyoga/sample-sales-data

# %%
import pandas as pd

df= pd.read_csv('sales_data_sample.csv', encoding='ISO-8859-1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
cols= df.shape[1]
cols
# Out:
# 25

# %%
col_names= df.columns
col_names
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %% [markdown]
# ## Normalization

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

numeric_data= df.select_dtypes(include=[np.number]).dropna()

std= StandardScaler()
scaledData= std.fit_transform(numeric_data)

# %% [markdown]
# ## Determining k

# %%
from sklearn.cluster import KMeans

ssd= []

k_range= range(1,11)

for k in k_range:
    kmeans= KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaledData)
    ssd.append(kmeans.inertia_)
# Out:
# /Users/shivanidangal/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/shivanidangal/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/shivanidangal/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# # Elbow Graph

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(k_range, ssd, marker='o', linestyle='-', color='c')
plt.title('Elbow method for optimal k')
plt.xlabel('Number of clusters(k)')
plt.ylabel('Sum of squared distances')
plt.grid(True)
plt.show()

# %%
optimal_k= 3#from the graph

model= KMeans(n_clusters=optimal_k, random_state=0)
model.fit(scaledData)
# Out:
# /Users/shivanidangal/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=0)

# %%
df['Clusters']= model.labels_

# %%
plt.scatter(df['SALES'],df['PRICEEACH'], c=df['Clusters'], cmap='plasma')
plt.title('K-means clustering')
plt.xlabel('Sales')
plt.ylabel('Price each')
plt.show()

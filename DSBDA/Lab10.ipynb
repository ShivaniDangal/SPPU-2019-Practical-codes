# %% [markdown]
# ##### Problem statement: Data Visualization III
#
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a boxplot for each feature in the dataset.
# 4. Compare distributions and identify outliers.

# %%
import pandas as pd
df= pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Features

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# # Boxplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig,axs= plt.subplots(2,2,figsize=(16,9))
sns.boxplot(data=df, x='Species', y='SepalLengthCm', ax= axs[0,0])
sns.boxplot(data=df, x='Species', y='SepalWidthCm', ax= axs[0,1])
sns.boxplot(data=df, x='Species', y='PetalLengthCm', ax= axs[1,0])
sns.boxplot(data=df, x='Species', y='PetalWidthCm', ax= axs[1,1])
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# # Outlier detection

# %%
import numpy as np

# %%
dfg= df.groupby('Species')
vir= (dfg.get_group('Iris-virginica'))
print(np.where(vir['SepalLengthCm']<5.5))
#print(np.where(df['SepalLengthCm']<5.5  df['Species']=='Iris-virginica'))
# Out:
# (array([6]),)

# %%
df.loc[6]
# Out:
# Id                         7
# SepalLengthCm            4.6
# SepalWidthCm             3.4
# PetalLengthCm            1.4
# PetalWidthCm             0.3
# Species          Iris-setosa
# Name: 6, dtype: object

# %% [markdown]
# similiarly can be done for other outliers

# %% [markdown]
# # Histogram

# %%
fig,axs= plt.subplots(2,2,figsize=(16,9))
sns.histplot(data=df, x='SepalLengthCm', ax= axs[0,0])
sns.histplot(data=df, x='SepalWidthCm', ax= axs[0,1])
sns.histplot(data=df, x='PetalLengthCm', ax= axs[1,0])
sns.histplot(data=df, x='PetalWidthCm', ax= axs[1,1])
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>
